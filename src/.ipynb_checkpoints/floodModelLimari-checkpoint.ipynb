# %%
# import generic packages
import numpy as np
from matplotlib import pyplot as plt

# import geospatial packages
import rasterio
from rasterio.plot import show
from shapely.geometry import LineString
import geopandas as gpd

# import landlab components
from landlab import RasterModelGrid, imshow_grid
from landlab.components.overland_flow import OverlandFlow
from landlab.components.overland_flow import KinwaveImplicitOverlandFlow

# %%
# Open raster image 
rasterObj = rasterio.open('../Rst/DEMLimari90Fill.tif')
show(rasterObj)
# Out:
# <Axes: >

# %%
#extract array from raster
elevArray = rasterObj.read(1)
plt.imshow(elevArray)

# %%
#create grid from raster attributes
nrows = rasterObj.height  # number of raster cells on each side, initially 150
ncols = rasterObj.width
dxy = (rasterObj.transform.a,-rasterObj.transform.e)  # side length of a raster model cell, or resolution [m], initially 50

# define a landlab raster
mg = RasterModelGrid(shape=(nrows, ncols), 
                     xy_spacing=dxy,
                     #xy_of_lower_left=(rasterObj.bounds[0],rasterObj.bounds[1]))
                     xy_of_lower_left=(0,0))

# show number of rows, cols and resolution
print(nrows, ncols, dxy)
# Out:
# 1508 1617 (90.0, 90.0)

# %%
# create a dataset of zero values
zr = mg.add_zeros("topographic__elevation", at="node")

# apply cell elevation to defined arrray
zr += elevArray[::-1,:].ravel()
print(zr)
imshow_grid(mg, "topographic__elevation", shrink=0.5)
# Out:
# [    0.             0.             0.         ...,  4054.18237305
#   4026.83398438  4001.22509766]

# %%
#set and apply and initial height
initialHeight = 0.5
depthArray = np.ones(elevArray.shape)*initialHeight
mg.at_node["surface_water__depth"] = depthArray

# %%
#define the flood objeds
of = OverlandFlow(mg, steep_slopes=True, rainfall_intensity=0.072/3600)

#list to store times
dtList = []

# %%
#Run once and store elapsed time
of.run_one_step()
dtList.append(of.dt)
print(of.dt)
# Out:
# 28.4505631082

# %%
# explore the output data and location

# model outputs
print(of.output_var_names)

# where this nodes are locates
print(of.var_loc("surface_water__depth"))

# show the water depth array
print(mg.at_node["surface_water__depth"])
# Out:
# ('surface_water__depth', 'surface_water__discharge', 'water_surface__gradient')
# node
# [ 0.50001  0.50001  0.50001 ...,  0.50001  0.50001  0.50001]

# %%
# plot the resulting water depth for the first run
imshow_grid(mg, "surface_water__depth", shrink=0.5)

# %%
# run the model for 100 time steps
for i in range(100):
    of.run_one_step()
    dtList.append(of.dt)
    print("Time step: %.2f seconds. Elapsed time %.2f seconds"%(of.dt,sum(dtList)))
# Out:
# Time step: 20.70 seconds. Elapsed time 49.15 seconds
# Time step: 16.63 seconds. Elapsed time 65.77 seconds
# Time step: 13.69 seconds. Elapsed time 79.46 seconds
# Time step: 11.57 seconds. Elapsed time 91.03 seconds
# Time step: 10.18 seconds. Elapsed time 101.21 seconds
# Time step: 9.06 seconds. Elapsed time 110.26 seconds
# Time step: 8.18 seconds. Elapsed time 118.44 seconds
# Time step: 7.51 seconds. Elapsed time 125.95 seconds
# Time step: 7.02 seconds. Elapsed time 132.97 seconds
# Time step: 6.67 seconds. Elapsed time 139.64 seconds
# Time step: 6.23 seconds. Elapsed time 145.87 seconds
# Time step: 5.93 seconds. Elapsed time 151.79 seconds
# Time step: 5.74 seconds. Elapsed time 157.54 seconds
# Time step: 5.62 seconds. Elapsed time 163.16 seconds
# Time step: 5.53 seconds. Elapsed time 168.69 seconds
# Time step: 3.24 seconds. Elapsed time 377.40 seconds
# Time step: 3.24 seconds. Elapsed time 380.64 seconds
# Time step: 3.23 seconds. Elapsed time 383.87 seconds
# Time step: 3.23 seconds. Elapsed time 387.10 seconds
# Time step: 3.23 seconds. Elapsed time 390.33 seconds
# Time step: 3.23 seconds. Elapsed time 393.56 seconds
# Time step: 3.23 seconds. Elapsed time 396.79 seconds
# Time step: 3.23 seconds. Elapsed time 400.02 seconds
# Time step: 3.23 seconds. Elapsed time 403.25 seconds
# Time step: 3.23 seconds. Elapsed time 406.47 seconds
# Time step: 3.22 seconds. Elapsed time 409.70 seconds
# Time step: 3.22 seconds. Elapsed time 412.92 seconds
# Time step: 3.22 seconds. Elapsed time 416.14 seconds
# Time step: 3.22 seconds. Elapsed time 419.37 seconds
# Time step: 3.22 seconds. Elapsed time 422.59 seconds
# Time step: 3.22 seconds. Elapsed time 425.81 seconds
# Time step: 3.22 seconds. Elapsed time 429.03 seconds
# Time step: 3.22 seconds. Elapsed time 432.25 seconds
# Time step: 3.22 seconds. Elapsed time 435.47 seconds
# Time step: 3.22 seconds. Elapsed time 438.69 seconds
# Time step: 3.22 seconds. Elapsed time 441.91 seconds
# Time step: 3.22 seconds. Elapsed time 445.13 seconds
# Time step: 3.22 seconds. Elapsed time 448.35 seconds
# Time step: 3.22 seconds. Elapsed time 451.57 seconds
# Time step: 3.22 seconds. Elapsed time 454.78 seconds
# Time step: 3.22 seconds. Elapsed time 458.00 seconds
# Time step: 3.22 seconds. Elapsed time 461.22 seconds
# Time step: 3.22 seconds. Elapsed time 464.43 seconds
# Time step: 3.22 seconds. Elapsed time 467.65 seconds

# %%
# plot the resulting water depth for the 101th run
imshow_grid(mg, "surface_water__depth", shrink=0.5,vmax=5)

# %%
#convert the resulting data to a numpy array
zArray = mg.at_node["surface_water__depth"].reshape((nrows,ncols))[::-1,:]
print(zArray)
# Out:
# [[ 0.50001     0.50001     0.50001    ...,  0.50001     0.50001
#    0.50001   ]
#  [ 0.50001     0.50072111  0.50084233 ...,  0.11624772  0.16962734
#    0.50001   ]
#  [ 0.50001     0.50084233  0.50101509 ...,  0.06743966  0.1867716
#    0.50001   ]
#  ...,
#  [ 0.50001     0.50084233  0.50101509 ...,  0.10303583  1.27422069
#    0.50001   ]
#  [ 0.50001     0.50072111  0.50084233 ...,  0.25251503  0.7714572
#    0.50001   ]
#  [ 0.50001     0.50001     0.50001    ...,  0.50001     0.50001
#    0.50001   ]]

# %%
import matplotlib.pyplot as plt

# Plot the array
fig, ax = plt.subplots()
cax = ax.imshow(zArray, vmax=1)

# Add a colorbar with a label
cbar = fig.colorbar(cax, ax=ax)
cbar.set_label('Altura de agua (m)', size=12)

plt.show()

# %%
# Write the array to a new GeoTIFF file
with rasterio.open(
        '../Out/floodSurfaceDepth.tif',
        'w',
        driver='GTiff',
        height=rasterObj.height,
        width=rasterObj.width,
        count=1,  # number of bands
        dtype=zArray.dtype,
        crs=rasterObj.crs,
        transform=rasterObj.transform
) as dst:
    dst.write(zArray, 1)  # write the data to the first band

# %%
# Show the resulting raster
floodObj = rasterio.open('../Out/floodSurfaceDepth.tif')
show(floodObj)
# Out:
# <Axes: >
